# %% [markdown]
# # 第XX章：实验标题
#
# 状态：模板，待学生填写。此模板仅演示运行环境和断言方式。
#
# ## 1. 学习目标与数学背景
# 待填写：问题、定义、假设、单位、边界条件及推导。
#
# ## 2. 实验方案
# 待填写：独立参考值、测试输入、误差指标、容差理由、随机种子、运行成本。

# %%
import sys
import numpy as np
rng = np.random.default_rng(2026)
print("Python:", sys.version.split()[0], "NumPy:", np.__version__)

# %% [markdown]
# ## 3. 实现与自检
# 以下恒等式只是模板示范，不算课程实验验证。

# %%
sample = np.array([1.0, 2.0, 3.0])
np.testing.assert_allclose(sample.mean(), 2.0)
print("模板自检通过；请补充本章算法与科学验证。")

# %% [markdown]
# ## 4. 结果与局限
# 待填写：真实输出、误差与收敛图、失败案例。
# ## 5. 课后习题
# 待填写：概念题、推导题、编程题、陷阱辨析题。题目与参考解答分开存放。
# ## 6. 来源与AI使用说明
# 待填写：文献、模型、日期、提示词记录位置与人工修订。
