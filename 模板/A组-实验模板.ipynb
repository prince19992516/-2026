# %% [markdown]
# # 第XX章：实验标题
#
# ![三格导入：观察有趣现象，提出可以检验的问题，用数学和实验寻找答案。](A组-导入插图模板.svg)
#
# *导入示意模板，非实测结果。复制到章节后按模板说明修改图片路径，并换成本章情境。*
#
# 状态：待学生填写。下面的均值计算仅用于演示操作，不是本章科学实验。
#
# ## 0. 先看一幕，再作预测
# 待填写：用一幅插图或两至三格漫画提出本章问题，用80—150字解释情境。人物可以幽默，数学对象、参数和假设必须明确。
#
# **我的预测：** 先写下预期结果及理由，再运行代码；即使猜错也保留原预测。
#
# **图意的边界：** 说明比喻对应什么、不能说明什么；示意曲线不能当作实验数据。
#
# ## 1. 学习目标与数学背景
# 待填写：问题、定义、假设、单位、边界条件及推导，把图中的问题翻译成数学语言。
#
# ## 2. 实验方案
# 待填写：独立参考值、输入、误差指标、容差理由、随机种子、运行成本，以及实验如何回答开场问题。

# %%
import sys
import numpy as np
rng = np.random.default_rng(2026)
print("Python:", sys.version.split()[0], "NumPy:", np.__version__)

# %% [markdown]
# ## 3. 实现与人工核对
# 先手算1、2、3的均值，再运行下面的代码比较。正式实验需替换为本章算法，并给出独立参考依据。

# %%
sample = np.array([1.0, 2.0, 3.0])
print("实际计算的均值：", sample.mean())
print("请与手算结果比较，并补充本章算法、参考值和误差分析。")

# %% [markdown]
# ## 4. 结果与局限
# 待填写：真实输出、误差与收敛图、失败案例。图表注明参数、坐标、单位及来源。
#
# ## 5. 回到开场问题
# 待填写：原先的预测是什么？推导与实际输出支持什么结论？哪一步解释了图中的现象？结论在哪些条件下成立，哪些情况尚未验证？
#
# ## 6. 课后习题
# 待填写：概念题、推导题、编程题、陷阱辨析题。题目与参考解答分开存放。
#
# ## 7. 来源与AI使用说明
# 待填写：文献、插图来源及使用许可；自行绘制或AI辅助绘图也要注明。A角色的模型、日期、提示词和人工修订写入本章A组-AI对话记录.md；B、C各自记录到对应角色文件。
