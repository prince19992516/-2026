# %% [markdown]
# # 第07章 B组验证
#
# 状态：待学生完成。当前只有占位说明，运行成功不代表完成验证。
#
# 先在B组-独立推导.md保存未查看A实现时的人工预期，再用另一AI辅助对比；查看固定A版本后，在新的课程副本和新建环境实际复现。填明参考值、容差依据与修正清单编号。
#
# ## 被审版本
# 填写A组完整commit。
#
# ## 方法与证据
# 填写独立方法、测试输入、预期结果、误差容限、实测结果和反例。
