# %% [markdown]
# # 第02章 函数逼近、数值积分与自动微分：起步实验
#
# > 状态：初始化示例，待三组复核；不是完整章节或已验收成果。
#
# ## 1. 学习目标
# 比较插值与逼近；用网格加密估计积分收敛阶；区分有限差分、符号微分与自动微分。
#
# ## 2. 数学背景与适用范围
# 复合梯形公式将每个小区间上的函数用直线近似。对 $[0,1]$ 上的光滑函数和等距步长 $h$，全局误差通常为 $O(h^2)$。令 $E_h$ 为绝对误差，$p=\log_2(E_h/E_{h/2})$ 可用于估计收敛阶；当误差接近舍入极限时，这个估计不再可靠。
#
# 本例使用 $f(x)=x^2$，积分真值为 $1/3$，梯形误差恰为 $1/(6n^2)$。它只示范积分；学生还需补齐插值、逼近与自动微分内容。
#
# ## 3. 实现与可执行断言
# 代码使用合成输入或解析函数，无需下载数据。断言检测上述具体示例，不构成一般正确性证明。

# %%
import numpy as np

def trapezoid_square(n):
    if not isinstance(n, int) or n < 1:
        raise ValueError("n must be a positive integer")
    x = np.linspace(0.0, 1.0, n + 1)
    y = x ** 2
    return (y[0] / 2 + y[1:-1].sum() + y[-1] / 2) / n

sizes = [8, 16, 32, 64]
errors = np.array([abs(trapezoid_square(n) - 1/3) for n in sizes])
orders = np.log2(errors[:-1] / errors[1:])
np.testing.assert_allclose(errors, [1/(6*n*n) for n in sizes], rtol=1e-9)
np.testing.assert_allclose(orders, 2.0, atol=1e-8)
print({"n": sizes, "errors": errors, "orders": orders})

# %% [markdown]
# ## 4. 学生扩展实验
# 补充多项式与样条逼近、节点选择、积分误差界及自动微分实验。
#
# ## 5. 课后习题
# 1. 手动推导本例梯形公式的精确误差 1/(6n²)。
# 2. 比较 Runge 函数的等距节点插值与 Chebyshev 节点插值，分别报告节点内和节点外误差。
# 3. 对一个复合标量函数手动应用链式法则，再比较有限差分、符号导数和自动微分；讨论步长选择。
# 4. 围绕“把插值节点上的零误差当成区间上逼近准确；把有限差分称为自动微分。”构造反例，说明为何普通测试可能漏检，并设计回归验证。
#
# ## 6. 结果、来源与AI记录
# 待填写：实际结果解释、图表、算法限制、参考资料和AI对话记录。重启内核并运行全部单元后再提交。
