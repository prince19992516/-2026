# %% [markdown]
# # 第04章 C组人工复核
#
# 状态：待学生完成。当前只有占位说明，运行成功不代表完成验证。
#
# 允许AI辅助提出漏洞、反例和验证代码。由C组人工核验关键推导、理解并运行代码、判断候选是否成立；分开标注人工编写和AI辅助部分，不把初始化示例当作学生已经完成的核验。
#
# ## 被审版本
# 填写A组完整commit及B组完整commit。
#
# ## 方法与证据
# 填写独立方法、测试输入、预期结果、误差容限、实测结果和反例。
#
# ## AI线索、代码来源与人工判断
# 待填写：提示词与真实回复、代码来源、人工修改和关键逻辑解释、实际输出、候选成立/不成立/未确定的依据。
